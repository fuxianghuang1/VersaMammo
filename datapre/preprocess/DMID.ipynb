# %% [markdown]
# DMID-breast

# %%
import os
import numpy as np
import pandas as pd
import pydicom as pdcm
import cv2

def np_CountUpContinuingOnes(b_arr):
    left = np.arange(len(b_arr))
    left[b_arr > 0] = 0
    left = np.maximum.accumulate(left)
    rev_arr = b_arr[::-1]
    right = np.arange(len(rev_arr))
    right[rev_arr > 0] = 0
    right = np.maximum.accumulate(right)
    right = len(rev_arr) - 1 - right[::-1]
    return right - left - 1

def ExtractBreast(img):
    img_copy = img.copy()
    img = np.where(img <= 40, 0, img)
    height, _ = img.shape
    y_a = height // 2 + int(height * 0.4)
    y_b = height // 2 - int(height * 0.4)
    b_arr = img[y_b:y_a].std(axis=0) != 0
    continuing_ones = np_CountUpContinuingOnes(b_arr)
    col_ind = np.where(continuing_ones == continuing_ones.max())[0]
    img = img[:, col_ind]
    _, width = img.shape
    x_a = width // 2 + int(width * 0.4)
    x_b = width // 2 - int(width * 0.4)
    b_arr = img[:, x_b:x_a].std(axis=1) != 0
    continuing_ones = np_CountUpContinuingOnes(b_arr)
    row_ind = np.where(continuing_ones == continuing_ones.max())[0]
    return img_copy[row_ind][:, col_ind]

# 读取数据划分CSV文件
split_csv_path = "../classification_data/classification_split.csv"
split_df = pd.read_csv(split_csv_path)
# 只保留DMID-breast数据集
split_df = split_df[split_df['dataset'] == 'DMID-breast']

# 读取XLSX文件
xlsx_path = '/Volumes/图图/DMID-kaggle/archive/Metadata.xlsx'
df = pd.read_excel(xlsx_path)

# 合并相同 ID 的数据
def merge_duplicates(df):
    merged_data = {}
    for _, row in df.iterrows():
        file_id = row['ID'].strip()
        view_dir = str(row['view']).replace(' ', '')
        left_or_right = 'Left' if view_dir.endswith('LT') else 'Right'
        background_tissue = str(row['background tissue']).replace(' ', '')

        if file_id in merged_data:
            if background_tissue != '-' and merged_data[file_id]['background_tissue'] != background_tissue:
                merged_data[file_id]['background_tissue'] = background_tissue
        else:
            merged_data[file_id] = {
                'view': view_dir,
                'left_or_right': left_or_right,
                'background_tissue': background_tissue
            }

    return merged_data

# 处理后的数据
merged_data = merge_duplicates(df)
df_sorted = pd.DataFrame(list(merged_data.items()), columns=['ID', 'data'])

# 合并数据划分信息
df_sorted = pd.merge(df_sorted, split_df[['data_name', 'data_split']], 
                    left_on='ID', right_on='data_name', how='inner')

# 定义输入和输出路径
DCM_PATH = "/Volumes/图图/DMID-kaggle/archive/DICOM Images/DICOM Images"
OUTPUT_BASE_PATH = "../classification_data/DMID"

def process_and_save():
    for _, row in df_sorted.iterrows():
        file_id = row['ID'].strip()
        data = row['data']
        data_split = row['data_split']
        background_tissue = data['background_tissue']

        meta_data = {
            'Composition': background_tissue,
        }
        if meta_data['Composition'] == '-':
            del meta_data['Composition']

        dcm_file = os.path.join(DCM_PATH, f"{file_id}.dcm")
        if os.path.exists(dcm_file):
            dcm = pdcm.dcmread(dcm_file)
            img = dcm.pixel_array
            if len(img.shape) == 3 and img.shape[2] == 3:
                img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            img = ExtractBreast(img)
            img = cv2.normalize(img, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)

            output_dir = os.path.join(OUTPUT_BASE_PATH, data_split, file_id)
            os.makedirs(output_dir, exist_ok=True)

            jpg_path = os.path.join(output_dir, 'img.jpg')
            cv2.imwrite(jpg_path, img)

            npy_path = os.path.join(output_dir, 'info_dict.npy')
            np.save(npy_path, meta_data)

            print(f"Processed {file_id} for {data_split} set")
        else:
            print(f"DICOM file for {file_id} not found.")

# 处理并保存数据
process_and_save()
print("Processing complete.")
# Out:
# Processed IMG406 for Train set
# Processed IMG223 for Train set
# Processed IMG403 for Train set
# Processed IMG215 for Train set
# Processed IMG161 for Train set
# Processed IMG008 for Train set
# Processed IMG027 for Train set
# Processed IMG423 for Train set
# Processed IMG062 for Train set
# Processed IMG046 for Train set
# Processed IMG278 for Train set
# Processed IMG141 for Train set
# Processed IMG082 for Train set
# Processed IMG264 for Train set
# Processed IMG362 for Train set
# Processed IMG271 for Train set
# Processed IMG093 for Train set
# Processed IMG419 for Train set
# Processed IMG231 for Train set
# Processed IMG371 for Train set
# Processed IMG092 for Train set
# Processed IMG038 for Train set
# Processed IMG383 for Train set
# Processed IMG368 for Train set
# Processed IMG272 for Train set
# Processed IMG067 for Train set
# Processed IMG455 for Train set
# Processed IMG444 for Train set
# Processed IMG053 for Train set
# Processed IMG460 for Train set
# Processed IMG244 for Train set
# Processed IMG081 for Train set
# Processed IMG138 for Train set
# Processed IMG057 for Train set
# Processed IMG140 for Train set
# Processed IMG120 for Train set
# Processed IMG467 for Train set
# Processed IMG228 for Train set
# Processed IMG139 for Train set
# Processed IMG233 for Train set
# Processed IMG344 for Train set
# Processed IMG068 for Train set
# Processed IMG171 for Train set
# Processed IMG084 for Train set
# Processed IMG510 for Train set
# Processed IMG332 for Train set
# Processed IMG126 for Train set
# Processed IMG445 for Train set
# Processed IMG192 for Train set
# Processed IMG509 for Train set
# Processed IMG286 for Train set
# Processed IMG109 for Train set
# Processed IMG166 for Train set
# Processed IMG238 for Train set
# Processed IMG454 for Train set
# Processed IMG111 for Train set
# Processed IMG328 for Train set
# Processed IMG354 for Train set
# Processed IMG334 for Train set
# Processed IMG415 for Train set
# Processed IMG466 for Train set
# Processed IMG491 for Train set
# Processed IMG482 for Train set
# Processed IMG320 for Train set
# Processed IMG412 for Train set
# Processed IMG459 for Train set
# Processed IMG206 for Train set
# Processed IMG473 for Train set
# Processed IMG119 for Train set
# Processed IMG474 for Train set
# Processed IMG471 for Train set
# Processed IMG208 for Train set
# Processed IMG147 for Train set
# Processed IMG273 for Train set
# Processed IMG339 for Train set
# Processed IMG029 for Train set
# Processed IMG469 for Train set
# Processed IMG035 for Train set
# Processed IMG185 for Train set
# Processed IMG191 for Train set
# Processed IMG263 for Train set
# Processed IMG097 for Train set
# Processed IMG179 for Train set
# Processed IMG261 for Train set
# Processed IMG287 for Train set
# Processed IMG347 for Train set
# Processed IMG433 for Train set
# Processed IMG066 for Train set
# Processed IMG104 for Train set
# Processed IMG386 for Train set
# Processed IMG114 for Train set
# Processed IMG269 for Train set
# Processed IMG470 for Train set
# Processed IMG044 for Train set
# Processed IMG180 for Train set
# Processed IMG284 for Train set
# Processed IMG017 for Train set
# Processed IMG164 for Train set
# Processed IMG088 for Train set
# Processed IMG312 for Train set
# Processed IMG441 for Train set
# Processed IMG309 for Train set
# Processed IMG260 for Train set
# Processed IMG011 for Train set
# Processed IMG448 for Train set
# Processed IMG295 for Train set
# Processed IMG146 for Train set
# Processed IMG176 for Train set
# Processed IMG137 for Train set
# Processed IMG387 for Train set
# Processed IMG294 for Train set
# Processed IMG259 for Train set
# Processed IMG052 for Train set
# Processed IMG484 for Train set
# Processed IMG240 for Train set
# Processed IMG363 for Train set
# Processed IMG300 for Train set
# Processed IMG124 for Train set
# Processed IMG422 for Train set
# Processed IMG392 for Train set
# Processed IMG495 for Train set
# Processed IMG030 for Train set
# Processed IMG408 for Train set
# Processed IMG504 for Train set
# Processed IMG393 for Train set
# Processed IMG167 for Train set
# Processed IMG384 for Train set
# Processed IMG277 for Train set
# Processed IMG298 for Train set
# Processed IMG308 for Train set
# Processed IMG154 for Train set
# Processed IMG159 for Train set
# Processed IMG361 for Train set
# Processed IMG492 for Train set
# Processed IMG489 for Train set
# Processed IMG325 for Train set
# Processed IMG072 for Train set
# Processed IMG063 for Train set
# Processed IMG378 for Train set
# Processed IMG106 for Train set
# Processed IMG464 for Train set
# Processed IMG381 for Train set
# Processed IMG178 for Train set
# Processed IMG028 for Train set
# Processed IMG430 for Train set
# Processed IMG346 for Train set
# Processed IMG390 for Train set
# Processed IMG150 for Train set
# Processed IMG405 for Train set
# Processed IMG436 for Train set
# Processed IMG152 for Train set
# Processed IMG224 for Train set
# Processed IMG316 for Train set
# Processed IMG170 for Train set
# Processed IMG065 for Train set
# Processed IMG487 for Train set
# Processed IMG037 for Train set
# Processed IMG212 for Train set
# Processed IMG016 for Train set
# Processed IMG456 for Train set
# Processed IMG220 for Train set
# Processed IMG327 for Train set
# Processed IMG200 for Train set
# Processed IMG404 for Train set
# Processed IMG451 for Train set
# Processed IMG055 for Train set
# Processed IMG135 for Train set
# Processed IMG480 for Train set
# Processed IMG314 for Train set
# Processed IMG163 for Train set
# Processed IMG373 for Train set
# Processed IMG157 for Train set
# Processed IMG059 for Train set
# Processed IMG307 for Train set
# Processed IMG376 for Train set
# Processed IMG131 for Train set
# Processed IMG060 for Train set
# Processed IMG039 for Train set
# Processed IMG478 for Train set
# Processed IMG113 for Train set
# Processed IMG021 for Train set
# Processed IMG486 for Train set
# Processed IMG187 for Train set
# Processed IMG234 for Train set
# Processed IMG315 for Train set
# Processed IMG143 for Train set
# Processed IMG214 for Train set
# Processed IMG490 for Train set
# Processed IMG305 for Train set
# Processed IMG304 for Train set
# Processed IMG134 for Train set
# Processed IMG042 for Train set
# Processed IMG268 for Train set
# Processed IMG310 for Train set
# Processed IMG274 for Train set
# Processed IMG399 for Train set
# Processed IMG391 for Train set
# Processed IMG463 for Train set
# Processed IMG051 for Train set
# Processed IMG043 for Train set
# Processed IMG319 for Train set
# Processed IMG428 for Train set
# Processed IMG417 for Train set
# Processed IMG421 for Train set
# Processed IMG440 for Train set
# Processed IMG254 for Train set
# Processed IMG380 for Train set
# Processed IMG186 for Train set
# Processed IMG022 for Train set
# Processed IMG061 for Train set
# Processed IMG377 for Train set
# Processed IMG222 for Train set
# Processed IMG130 for Train set
# Processed IMG401 for Train set
# Processed IMG204 for Train set
# Processed IMG032 for Train set
# Processed IMG366 for Train set
# Processed IMG357 for Train set
# Processed IMG352 for Train set
# Processed IMG054 for Train set
# Processed IMG414 for Train set
# Processed IMG108 for Train set
# Processed IMG169 for Train set
# Processed IMG024 for Train set
# Processed IMG407 for Train set
# Processed IMG237 for Train set
# Processed IMG499 for Train set
# Processed IMG306 for Train set
# Processed IMG267 for Train set
# Processed IMG162 for Train set
# Processed IMG318 for Train set
# Processed IMG434 for Train set
# Processed IMG255 for Train set
# Processed IMG367 for Train set
# Processed IMG498 for Train set
# Processed IMG005 for Train set
# Processed IMG190 for Train set
# Processed IMG256 for Train set
# Processed IMG045 for Train set
# Processed IMG089 for Train set
# Processed IMG121 for Train set
# Processed IMG123 for Train set
# Processed IMG246 for Train set
# Processed IMG301 for Train set
# Processed IMG225 for Train set
# Processed IMG462 for Train set
# Processed IMG397 for Train set
# Processed IMG317 for Train set
# Processed IMG216 for Train set
# Processed IMG353 for Train set
# Processed IMG175 for Train set
# Processed IMG026 for Train set
# Processed IMG218 for Train set
# Processed IMG086 for Train set
# Processed IMG227 for Train set
# Processed IMG009 for Train set
# Processed IMG292 for Train set
# Processed IMG503 for Train set
# Processed IMG090 for Train set
# Processed IMG004 for Train set
# Processed IMG291 for Train set
# Processed IMG279 for Train set
# Processed IMG087 for Train set
# Processed IMG483 for Train set
# Processed IMG280 for Train set
# Processed IMG394 for Train set
# Processed IMG199 for Train set
# Processed IMG058 for Train set
# Processed IMG253 for Train set
# Processed IMG050 for Train set
# Processed IMG411 for Train set
# Processed IMG379 for Train set
# Processed IMG329 for Train set
# Processed IMG036 for Train set
# Processed IMG165 for Train set
# Processed IMG116 for Train set
# Processed IMG041 for Train set
# Processed IMG345 for Train set
# Processed IMG396 for Train set
# Processed IMG122 for Train set
# Processed IMG331 for Train set
# Processed IMG338 for Train set
# Processed IMG048 for Train set
# Processed IMG337 for Train set
# Processed IMG313 for Train set
# Processed IMG018 for Train set
# Processed IMG439 for Train set
# Processed IMG385 for Train set
# Processed IMG252 for Train set
# Processed IMG101 for Train set
# Processed IMG153 for Train set
# Processed IMG266 for Train set
# Processed IMG350 for Train set
# Processed IMG497 for Train set
# Processed IMG115 for Train set
# Processed IMG457 for Train set
# Processed IMG333 for Train set
# Processed IMG437 for Train set
# Processed IMG142 for Train set
# Processed IMG340 for Train set
# Processed IMG232 for Train set
# Processed IMG014 for Train set
# Processed IMG172 for Train set
# Processed IMG508 for Train set
# Processed IMG275 for Train set
# Processed IMG202 for Train set
# Processed IMG322 for Train set
# Processed IMG201 for Train set
# Processed IMG144 for Train set
# Processed IMG493 for Train set
# Processed IMG189 for Train set
# Processed IMG290 for Train set
# Processed IMG213 for Train set
# Processed IMG100 for Train set
# Processed IMG402 for Train set
# Processed IMG096 for Train set
# Processed IMG209 for Train set
# Processed IMG446 for Train set
# Processed IMG355 for Train set
# Processed IMG247 for Train set
# Processed IMG335 for Train set
# Processed IMG349 for Train set
# Processed IMG429 for Train set
# Processed IMG098 for Train set
# Processed IMG395 for Train set
# Processed IMG095 for Train set
# Processed IMG242 for Train set
# Processed IMG013 for Train set
# Processed IMG207 for Train set
# Processed IMG239 for Train set
# Processed IMG351 for Train set
# Processed IMG148 for Train set
# Processed IMG398 for Train set
# Processed IMG410 for Train set
# Processed IMG258 for Train set
# Processed IMG015 for Train set
# Processed IMG265 for Train set
# Processed IMG257 for Train set
# Processed IMG500 for Train set
# Processed IMG288 for Train set
# Processed IMG197 for Train set
# Processed IMG389 for Train set
# Processed IMG364 for Train set
# Processed IMG194 for Train set
# Processed IMG236 for Train set
# Processed IMG205 for Train set
# Processed IMG420 for Train set
# Processed IMG356 for Train set
# Processed IMG425 for Train set
# Processed IMG103 for Train set
# Processed IMG501 for Train set
# Processed IMG485 for Train set
# Processed IMG465 for Train set
# Processed IMG229 for Train set
# Processed IMG033 for Train set
# Processed IMG388 for Train set
# Processed IMG488 for Train set
# Processed IMG193 for Eval set
# Processed IMG128 for Eval set
# Processed IMG458 for Eval set
# Processed IMG127 for Eval set
# Processed IMG025 for Eval set
# Processed IMG158 for Eval set
# Processed IMG112 for Eval set
# Processed IMG431 for Eval set
# Processed IMG241 for Eval set
# Processed IMG293 for Eval set
# Processed IMG188 for Eval set
# Processed IMG477 for Eval set
# Processed IMG136 for Eval set
# Processed IMG360 for Eval set
# Processed IMG321 for Eval set
# Processed IMG427 for Eval set
# Processed IMG358 for Eval set
# Processed IMG243 for Eval set
# Processed IMG076 for Eval set
# Processed IMG374 for Eval set
# Processed IMG006 for Eval set
# Processed IMG107 for Eval set
# Processed IMG129 for Eval set
# Processed IMG160 for Eval set
# Processed IMG289 for Eval set
# Processed IMG296 for Eval set
# Processed IMG145 for Eval set
# Processed IMG198 for Eval set
# Processed IMG184 for Eval set
# Processed IMG020 for Eval set
# Processed IMG372 for Eval set
# Processed IMG262 for Eval set
# Processed IMG311 for Eval set
# Processed IMG235 for Eval set
# Processed IMG283 for Eval set
# Processed IMG099 for Eval set
# Processed IMG117 for Eval set
# Processed IMG270 for Eval set
# Processed IMG195 for Eval set
# Processed IMG002 for Eval set
# Processed IMG217 for Eval set
# Processed IMG507 for Eval set
# Processed IMG007 for Eval set
# Processed IMG075 for Eval set
# Processed IMG110 for Eval set
# Processed IMG468 for Eval set
# Processed IMG432 for Eval set
# Processed IMG049 for Eval set
# Processed IMG203 for Eval set
# Processed IMG479 for Eval set
# Processed IMG151 for Eval set
# Processed IMG481 for Test set
# Processed IMG450 for Test set
# Processed IMG476 for Test set
# Processed IMG435 for Test set
# Processed IMG369 for Test set
# Processed IMG056 for Test set
# Processed IMG323 for Test set
# Processed IMG077 for Test set
# Processed IMG505 for Test set
# Processed IMG348 for Test set
# Processed IMG416 for Test set
# Processed IMG221 for Test set
# Processed IMG118 for Test set
# Processed IMG250 for Test set
# Processed IMG174 for Test set
# Processed IMG094 for Test set
# Processed IMG326 for Test set
# Processed IMG276 for Test set
# Processed IMG343 for Test set
# Processed IMG071 for Test set
# Processed IMG506 for Test set
# Processed IMG010 for Test set
# Processed IMG251 for Test set
# Processed IMG409 for Test set
# Processed IMG424 for Test set
# Processed IMG452 for Test set
# Processed IMG173 for Test set
# Processed IMG031 for Test set
# Processed IMG449 for Test set
# Processed IMG091 for Test set
# Processed IMG382 for Test set
# Processed IMG132 for Test set
# Processed IMG365 for Test set
# Processed IMG074 for Test set
# Processed IMG211 for Test set
# Processed IMG330 for Test set
# Processed IMG370 for Test set
# Processed IMG102 for Test set
# Processed IMG219 for Test set
# Processed IMG155 for Test set
# Processed IMG226 for Test set
# Processed IMG400 for Test set
# Processed IMG064 for Test set
# Processed IMG003 for Test set
# Processed IMG442 for Test set
# Processed IMG341 for Test set
# Processed IMG083 for Test set
# Processed IMG285 for Test set
# Processed IMG210 for Test set
# Processed IMG472 for Test set
# Processed IMG182 for Test set
# Processed IMG078 for Test set
# Processed IMG297 for Test set
# Processed IMG453 for Test set
# Processed IMG496 for Test set
# Processed IMG426 for Test set
# Processed IMG034 for Test set
# Processed IMG080 for Test set
# Processed IMG418 for Test set
# Processed IMG168 for Test set
# Processed IMG069 for Test set
# Processed IMG001 for Test set
# Processed IMG085 for Test set
# Processed IMG012 for Test set
# Processed IMG230 for Test set
# Processed IMG023 for Test set
# Processed IMG324 for Test set
# Processed IMG079 for Test set
# Processed IMG248 for Test set
# Processed IMG073 for Test set
# Processed IMG475 for Test set
# Processed IMG336 for Test set
# Processed IMG019 for Test set
# Processed IMG281 for Test set
# Processed IMG125 for Test set
# Processed IMG443 for Test set
# Processed IMG249 for Test set
# Processed IMG040 for Test set
# Processed IMG461 for Test set
# Processed IMG047 for Test set
# Processed IMG302 for Test set
# Processed IMG196 for Test set
# Processed IMG359 for Test set
# Processed IMG105 for Test set
# Processed IMG282 for Test set
# Processed IMG149 for Test set
# Processed IMG156 for Test set
# Processed IMG447 for Test set
# Processed IMG183 for Test set
# Processed IMG070 for Test set
# Processed IMG245 for Test set
# Processed IMG299 for Test set
# Processed IMG413 for Test set
# Processed IMG502 for Test set
# Processed IMG303 for Test set
# Processed IMG494 for Test set
# Processed IMG181 for Test set
# Processed IMG375 for Test set
# Processed IMG133 for Test set
# Processed IMG342 for Test set
# Processed IMG438 for Test set
# Processed IMG177 for Test set

# %% [markdown]
# DMID-finding

# %%
import os
import numpy as np
import pandas as pd
import pydicom as pdcm
import cv2

def crop_and_save(img, x, y, radius, output_path):
    flag = True
    try:
        x = int(x)
        y = int(y)
        radius = int(radius)
        x1 = max(x - radius, 0)
        y1 = max(y - radius, 0)
        x2 = min(x + radius, img.shape[1])
        y2 = min(y + radius, img.shape[0])

        # 裁剪图像
        cropped_img = img[y1:y2, x1:x2]
        cropped_img = cv2.normalize(cropped_img, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
        os.makedirs(os.path.dirname(output_path), exist_ok=True)
        cv2.imwrite(output_path, cropped_img)
    except:
        flag = False
    return flag

# 读取数据划分CSV文件
split_csv_path = "../classification_data/classification_split.csv"
split_df = pd.read_csv(split_csv_path)
# 只保留DMID-finding数据集
split_df = split_df[split_df['dataset'] == 'DMID-finding']

# 读取XLSX文件
xlsx_path = '/Volumes/图图/DMID-kaggle/archive/Metadata.xlsx'
df = pd.read_excel(xlsx_path)
df = df[df['abnormality'].replace(' ', '') != 'NORM']

# 定义输入和输出路径
DCM_PATH = "/Volumes/图图/DMID-kaggle/archive/DICOM Images/DICOM Images"
OUTPUT_BASE_PATH = "../classification_data/DMID-finding"

def process_and_save():
    global_counter = {}  # 用于生成唯一后缀的计数器
    
    for index, row in df.iterrows():
        # 获取 abnormality 信息
        abnormality = str(row['abnormality']).replace(' ', '')
        pathology = str(row['pathology']).replace(' ', '')

        # 处理 pathology 字段
        if pathology == 'N':
            pathology = 'B'
        
        # 将 abnormality 中的 + 号处理为列表
        abnormality = abnormality.split('+') if '+' in abnormality else [abnormality]
        
        # 构建元数据
        info_dict = {
            'Finding': abnormality,
            'Pathology': pathology
        }
        if 'Finding' in info_dict:
            updated_categories = []
            for category in info_dict['Finding']:
                if category == 'CALC' or category == 'CLAC':
                    updated_categories.append('Calcification')
                elif category == 'CIRC':
                    updated_categories.append('Circumscribed masses')
                elif category == 'SPIC':
                    updated_categories.append('Spiculated masses')
                elif category == 'ARCH':
                    updated_categories.append('Architectural distortion')
                elif category == 'ASYM':
                    updated_categories.append('Asymmetry')
                elif category == 'MISC':
                    updated_categories.append('Miscellaneous')
            if updated_categories:
                info_dict['Finding'] = updated_categories
        
        if 'Pathology' in info_dict:
            if info_dict['Pathology'] == 'B':
                info_dict['Pathology'] = 'Benign'
            elif info_dict['Pathology'] == 'M':
                info_dict['Pathology'] = 'Malignant'

        file_id = row['ID'].strip()
        x, y, radius = row['x'], row['y'], row['radius']

        # 更新ID计数器，确保每个file_id有唯一后缀
        if file_id in global_counter:
            global_counter[file_id] += 1
        else:
            global_counter[file_id] = 1
        file_id_with_suffix = f"{file_id}_{global_counter[file_id]}"

        # 查找对应的data_split
        split_info = split_df[split_df['data_name'] == file_id_with_suffix]
        if split_info.empty:
            print(f"No split info found for {file_id_with_suffix}")
            continue
            
        data_split = split_info['data_split'].values[0]

        # 处理DICOM文件
        dcm_file = os.path.join(DCM_PATH, f"{file_id}.dcm")
        if os.path.exists(dcm_file):
            dcm = pdcm.dcmread(dcm_file)
            img = dcm.pixel_array
            if img.ndim == 3 and img.shape[2] == 3:
                img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            # 创建输出目录
            output_dir = os.path.join(OUTPUT_BASE_PATH, data_split, file_id_with_suffix)

            # 裁剪并保存预处理后的图像为JPG文件
            jpg_path = os.path.join(output_dir, 'img.jpg')
            flag = crop_and_save(img, x, y, radius, jpg_path)

            # 保存元数据为NPY文件
            if flag:
                npy_path = os.path.join(output_dir, 'info_dict.npy')
                np.save(npy_path, info_dict)
                print(f"Processed {file_id_with_suffix} for {data_split} set")
        else:
            print(f"DICOM file for {file_id} not found.")

# 处理并保存数据
process_and_save()
print("Processing complete.")
# Out:
# Processed IMG283 for Train set as IMG283_1
# Processed IMG459 for Train set as IMG459_1
# Processed IMG085 for Train set as IMG085_1
# Processed IMG288 for Train set as IMG288_1
# Processed IMG315 for Train set as IMG315_1
# Processed IMG277 for Train set as IMG277_1
# Processed IMG064 for Train set as IMG064_1
# Processed IMG489 for Train set as IMG489_1
# Processed IMG278 for Train set as IMG278_1
# Processed IMG283 for Train set as IMG283_2
# Processed IMG132 for Train set as IMG132_1
# Processed IMG305 for Train set as IMG305_1
# Processed IMG090 for Train set as IMG090_1
# Processed IMG306 for Train set as IMG306_1
# Processed IMG144 for Train set as IMG144_1
# Processed IMG150 for Train set as IMG150_1
# Processed IMG476 for Train set as IMG476_1
# Processed IMG369 for Train set as IMG369_1
# Processed IMG323 for Train set as IMG323_1
# Processed IMG301 for Train set as IMG301_1
# Processed IMG294 for Train set as IMG294_1
# Processed IMG410 for Train set as IMG410_1
# Processed IMG066 for Train set as IMG066_1
# Processed IMG474 for Train set as IMG474_1
# Processed IMG491 for Train set as IMG491_1
# Processed IMG254 for Train set as IMG254_1
# Processed IMG048 for Train set as IMG048_1
# Processed IMG385 for Train set as IMG385_1
# Processed IMG358 for Train set as IMG358_1
# Processed IMG057 for Train set as IMG057_1
# Processed IMG131 for Train set as IMG131_1
# Processed IMG065 for Train set as IMG065_1
# Processed IMG114 for Train set as IMG114_1
# Processed IMG203 for Train set as IMG203_1
# Processed IMG475 for Train set as IMG475_1
# Processed IMG421 for Train set as IMG421_1
# Processed IMG417 for Train set as IMG417_1
# Processed IMG058 for Train set as IMG058_1
# Processed IMG407 for Train set as IMG407_1
# Processed IMG278 for Train set as IMG278_2
# Processed IMG441 for Train set as IMG441_1
# Processed IMG478 for Train set as IMG478_1
# Processed IMG279 for Train set as IMG279_1
# Processed IMG272 for Train set as IMG272_1
# Processed IMG418 for Train set as IMG418_1
# Processed IMG367 for Train set as IMG367_1
# Processed IMG439 for Train set as IMG439_1
# Processed IMG318 for Train set as IMG318_1
# Processed IMG288 for Train set as IMG288_2
# Processed IMG500 for Train set as IMG500_1
# Processed IMG326 for Train set as IMG326_1
# Processed IMG024 for Train set as IMG024_1
# Processed IMG234 for Train set as IMG234_1
# Processed IMG473 for Train set as IMG473_1
# Processed IMG291 for Train set as IMG291_1
# Processed IMG487 for Train set as IMG487_1
# Processed IMG041 for Train set as IMG041_1
# Processed IMG286 for Train set as IMG286_1
# Processed IMG011 for Train set as IMG011_1
# Processed IMG114 for Train set as IMG114_2
# Processed IMG020 for Train set as IMG020_1
# Processed IMG367 for Train set as IMG367_2
# Processed IMG410 for Train set as IMG410_2
# Processed IMG233 for Train set as IMG233_1
# Processed IMG383 for Train set as IMG383_1
# Processed IMG053 for Train set as IMG053_1
# Processed IMG114 for Train set as IMG114_3
# Processed IMG453 for Train set as IMG453_1
# Processed IMG414 for Train set as IMG414_1
# Processed IMG011 for Train set as IMG011_2
# Processed IMG102 for Train set as IMG102_1
# Processed IMG112 for Train set as IMG112_1
# Processed IMG316 for Train set as IMG316_1
# Processed IMG186 for Train set as IMG186_1
# Processed IMG063 for Train set as IMG063_1
# Processed IMG394 for Train set as IMG394_1
# Processed IMG415 for Train set as IMG415_1
# Processed IMG408 for Train set as IMG408_1
# Processed IMG284 for Train set as IMG284_1
# Processed IMG065 for Train set as IMG065_2
# Processed IMG406 for Train set as IMG406_1
# Processed IMG412 for Train set as IMG412_1
# Processed IMG457 for Train set as IMG457_1
# Processed IMG274 for Train set as IMG274_1
# Processed IMG428 for Train set as IMG428_1
# Processed IMG369 for Train set as IMG369_2
# Processed IMG322 for Train set as IMG322_1
# Processed IMG410 for Train set as IMG410_3
# Processed IMG101 for Train set as IMG101_1
# Processed IMG357 for Train set as IMG357_1
# Processed IMG468 for Train set as IMG468_1
# Processed IMG278 for Train set as IMG278_3
# Processed IMG488 for Train set as IMG488_1
# Processed IMG184 for Train set as IMG184_1
# Processed IMG292 for Train set as IMG292_1
# Processed IMG274 for Train set as IMG274_2
# Processed IMG276 for Train set as IMG276_1
# Processed IMG142 for Train set as IMG142_1
# Processed IMG117 for Train set as IMG117_1
# Processed IMG444 for Train set as IMG444_1
# Processed IMG324 for Train set as IMG324_1
# Processed IMG408 for Train set as IMG408_2
# Processed IMG067 for Train set as IMG067_1
# Processed IMG494 for Train set as IMG494_1
# Processed IMG383 for Train set as IMG383_2
# Processed IMG409 for Train set as IMG409_1
# Processed IMG084 for Train set as IMG084_1
# Processed IMG342 for Train set as IMG342_1
# Processed IMG286 for Train set as IMG286_2
# Processed IMG362 for Train set as IMG362_1
# Processed IMG097 for Train set as IMG097_1
# Processed IMG322 for Train set as IMG322_2
# Processed IMG059 for Train set as IMG059_1
# Processed IMG431 for Train set as IMG431_1
# Processed IMG311 for Train set as IMG311_1
# Processed IMG450 for Train set as IMG450_1
# Processed IMG086 for Train set as IMG086_1
# Processed IMG145 for Train set as IMG145_1
# Processed IMG021 for Train set as IMG021_1
# Processed IMG446 for Train set as IMG446_1
# Processed IMG405 for Train set as IMG405_1
# Processed IMG466 for Train set as IMG466_1
# Processed IMG309 for Train set as IMG309_1
# Processed IMG456 for Train set as IMG456_1
# Processed IMG409 for Train set as IMG409_2
# Processed IMG143 for Train set as IMG143_1
# Processed IMG143 for Train set as IMG143_2
# Processed IMG148 for Train set as IMG148_1
# Processed IMG031 for Train set as IMG031_1
# Processed IMG297 for Train set as IMG297_1
# Processed IMG105 for Train set as IMG105_1
# Processed IMG471 for Train set as IMG471_1
# Processed IMG445 for Train set as IMG445_1
# Processed IMG191 for Train set as IMG191_1
# Processed IMG357 for Train set as IMG357_2
# Processed IMG445 for Train set as IMG445_2
# Processed IMG357 for Train set as IMG357_3
# Processed IMG186 for Train set as IMG186_2
# Processed IMG438 for Train set as IMG438_1
# Processed IMG184 for Train set as IMG184_2
# Processed IMG056 for Train set as IMG056_1
# Processed IMG424 for Train set as IMG424_1
# Processed IMG140 for Train set as IMG140_1
# Processed IMG419 for Train set as IMG419_1
# Processed IMG324 for Train set as IMG324_2
# Processed IMG319 for Train set as IMG319_1
# Processed IMG206 for Train set as IMG206_1
# Processed IMG262 for Train set as IMG262_1
# Processed IMG355 for Train set as IMG355_1
# Processed IMG370 for Train set as IMG370_1
# Processed IMG201 for Train set as IMG201_1
# Processed IMG158 for Train set as IMG158_1
# Processed IMG420 for Train set as IMG420_1
# Processed IMG001 for Train set as IMG001_1
# Processed IMG161 for Train set as IMG161_1
# Processed IMG410 for Train set as IMG410_4
# Processed IMG275 for Train set as IMG275_1
# Processed IMG081 for Train set as IMG081_1
# Processed IMG025 for Train set as IMG025_1
# Processed IMG416 for Train set as IMG416_1
# Processed IMG480 for Train set as IMG480_1
# Processed IMG422 for Train set as IMG422_1
# Processed IMG286 for Train set as IMG286_3
# Processed IMG443 for Train set as IMG443_1
# Processed IMG104 for Train set as IMG104_1
# Processed IMG429 for Train set as IMG429_1
# Processed IMG116 for Train set as IMG116_1
# Processed IMG403 for Train set as IMG403_1
# Processed IMG164 for Train set as IMG164_1
# Processed IMG296 for Train set as IMG296_1
# Processed IMG040 for Train set as IMG040_1
# Processed IMG287 for Train set as IMG287_1
# Processed IMG222 for Train set as IMG222_1
# Processed IMG286 for Train set as IMG286_4
# Processed IMG279 for Train set as IMG279_2
# Processed IMG116 for Train set as IMG116_2
# Processed IMG010 for Train set as IMG010_1
# Processed IMG118 for Train set as IMG118_1
# Processed IMG233 for Train set as IMG233_2
# Processed IMG308 for Train set as IMG308_1
# Processed IMG311 for Train set as IMG311_2
# Processed IMG467 for Train set as IMG467_1
# Processed IMG284 for Train set as IMG284_2
# Processed IMG501 for Train set as IMG501_1
# Processed IMG282 for Train set as IMG282_1
# Processed IMG012 for Train set as IMG012_1
# Processed IMG060 for Train set as IMG060_1
# Processed IMG478 for Train set as IMG478_2
# Processed IMG039 for Train set as IMG039_1
# Processed IMG426 for Train set as IMG426_1
# Processed IMG029 for Train set as IMG029_1
# Processed IMG421 for Train set as IMG421_2
# Processed IMG186 for Train set as IMG186_3
# Processed IMG201 for Train set as IMG201_2
# Processed IMG028 for Train set as IMG028_1
# Processed IMG136 for Train set as IMG136_1
# Processed IMG026 for Train set as IMG026_1
# Processed IMG277 for Train set as IMG277_2
# Processed IMG186 for Train set as IMG186_4
# Processed IMG059 for Train set as IMG059_2
# Processed IMG033 for Train set as IMG033_1
# Processed IMG024 for Train set as IMG024_2
# Processed IMG252 for Train set as IMG252_1
# Processed IMG328 for Train set as IMG328_1
# Processed IMG417 for Train set as IMG417_2
# Processed IMG206 for Train set as IMG206_2
# Processed IMG108 for Train set as IMG108_1
# Processed IMG411 for Train set as IMG411_1
# Processed IMG253 for Train set as IMG253_1
# Processed IMG297 for Train set as IMG297_2
# Processed IMG220 for Train set as IMG220_1
# Processed IMG184 for Train set as IMG184_3
# Processed IMG447 for Train set as IMG447_1
# Processed IMG116 for Train set as IMG116_3
# Processed IMG129 for Train set as IMG129_1
# Processed IMG288 for Train set as IMG288_3
# Processed IMG299 for Train set as IMG299_1
# Processed IMG204 for Train set as IMG204_1
# Processed IMG407 for Train set as IMG407_2
# Processed IMG285 for Train set as IMG285_1
# Processed IMG202 for Train set as IMG202_1
# Processed IMG470 for Train set as IMG470_1
# Processed IMG404 for Train set as IMG404_1
# Processed IMG448 for Train set as IMG448_1
# Processed IMG149 for Train set as IMG149_1
# Processed IMG286 for Train set as IMG286_5
# Processed IMG068 for Train set as IMG068_1
# Processed IMG103 for Train set as IMG103_1
# Processed IMG232 for Train set as IMG232_1
# Processed IMG427 for Train set as IMG427_1
# Processed IMG407 for Train set as IMG407_3
# Processed IMG288 for Train set as IMG288_4
# Processed IMG141 for Train set as IMG141_1
# Processed IMG027 for Train set as IMG027_1
# Processed IMG278 for Train set as IMG278_4
# Processed IMG219 for Train set as IMG219_1
# Processed IMG048 for Train set as IMG048_2
# Processed IMG142 for Train set as IMG142_2
# Processed IMG034 for Train set as IMG034_1
# Processed IMG147 for Train set as IMG147_1
# Processed IMG059 for Train set as IMG059_3
# Processed IMG295 for Train set as IMG295_1
# Processed IMG139 for Train set as IMG139_1
# Processed IMG133 for Train set as IMG133_1
# Processed IMG310 for Train set as IMG310_1
# Processed IMG358 for Train set as IMG358_2
# Processed IMG251 for Train set as IMG251_1
# Processed IMG441 for Train set as IMG441_2
# Processed IMG469 for Train set as IMG469_1
# Processed IMG046 for Train set as IMG046_1
# Processed IMG045 for Train set as IMG045_1
# Processed IMG082 for Train set as IMG082_1
# Processed IMG184 for Train set as IMG184_4
# Processed IMG067 for Train set as IMG067_2
# Processed IMG200 for Train set as IMG200_1
# Processed IMG437 for Train set as IMG437_1
# Processed IMG030 for Train set as IMG030_1
# Processed IMG065 for Train set as IMG065_3
# Processed IMG339 for Train set as IMG339_1
# Processed IMG062 for Train set as IMG062_1
# Processed IMG415 for Train set as IMG415_2
# Processed IMG455 for Train set as IMG455_1
# Processed IMG030 for Train set as IMG030_2
# Processed IMG451 for Train set as IMG451_1
# Processed IMG257 for Train set as IMG257_1
# Processed IMG470 for Train set as IMG470_2
# Processed IMG327 for Train set as IMG327_1
# Processed IMG252 for Train set as IMG252_2
# Processed IMG329 for Train set as IMG329_1
# Processed IMG199 for Train set as IMG199_1
# Processed IMG106 for Train set as IMG106_1
# Processed IMG499 for Train set as IMG499_1
# Processed IMG288 for Train set as IMG288_5
# Processed IMG358 for Train set as IMG358_3
# Processed IMG479 for Train set as IMG479_1
# Processed IMG408 for Train set as IMG408_3
# Processed IMG139 for Train set as IMG139_2
# Processed IMG419 for Train set as IMG419_2
# Processed IMG429 for Train set as IMG429_2
# Processed IMG367 for Train set as IMG367_3
# Processed IMG458 for Train set as IMG458_1
# Processed IMG014 for Train set as IMG014_1
# Processed IMG465 for Train set as IMG465_1
# Processed IMG300 for Train set as IMG300_1
# Processed IMG140 for Train set as IMG140_2
# Processed IMG325 for Train set as IMG325_1
# Processed IMG116 for Train set as IMG116_4
# Processed IMG433 for Train set as IMG433_1
# Processed IMG022 for Train set as IMG022_1
# Processed IMG497 for Train set as IMG497_1
# Processed IMG423 for Train set as IMG423_1
# Processed IMG414 for Train set as IMG414_2
# Processed IMG138 for Train set as IMG138_1
# Processed IMG161 for Train set as IMG161_2
# Processed IMG409 for Train set as IMG409_3
# Processed IMG331 for Train set as IMG331_1
# Processed IMG412 for Train set as IMG412_2
# Processed IMG008 for Train set as IMG008_1
# Processed IMG111 for Train set as IMG111_1
# Processed IMG172 for Train set as IMG172_1
# Processed IMG367 for Train set as IMG367_4
# Processed IMG073 for Train set as IMG073_1
# Processed IMG043 for Train set as IMG043_1
# Processed IMG470 for Train set as IMG470_3
# Processed IMG502 for Train set as IMG502_1
# Processed IMG018 for Train set as IMG018_1
# Processed IMG436 for Eval set as IMG436_2
# Processed IMG012 for Eval set as IMG012_2
# Processed IMG038 for Eval set as IMG038_1
# Processed IMG298 for Eval set as IMG298_1
# Processed IMG146 for Eval set as IMG146_1
# Processed IMG416 for Eval set as IMG416_2
# Processed IMG205 for Eval set as IMG205_1
# Processed IMG483 for Eval set as IMG483_1
# Processed IMG357 for Eval set as IMG357_4
# Processed IMG279 for Eval set as IMG279_3
# Processed IMG159 for Eval set as IMG159_1
# Processed IMG425 for Eval set as IMG425_1
# Processed IMG369 for Eval set as IMG369_3
# Processed IMG409 for Eval set as IMG409_4
# Processed IMG135 for Eval set as IMG135_1
# Processed IMG094 for Eval set as IMG094_1
# Processed IMG322 for Eval set as IMG322_3
# Processed IMG134 for Eval set as IMG134_1
# Processed IMG326 for Eval set as IMG326_2
# Processed IMG312 for Eval set as IMG312_1
# Processed IMG355 for Eval set as IMG355_2
# Processed IMG460 for Eval set as IMG460_1
# Processed IMG146 for Eval set as IMG146_2
# Processed IMG317 for Eval set as IMG317_1
# Processed IMG419 for Eval set as IMG419_3
# Processed IMG402 for Eval set as IMG402_1
# Processed IMG061 for Eval set as IMG061_1
# Processed IMG482 for Eval set as IMG482_1
# Processed IMG434 for Eval set as IMG434_1
# Processed IMG413 for Eval set as IMG413_1
# Processed IMG355 for Eval set as IMG355_3
# Processed IMG088 for Eval set as IMG088_1
# Processed IMG324 for Eval set as IMG324_3
# Processed IMG280 for Eval set as IMG280_1
# Processed IMG166 for Eval set as IMG166_1
# Processed IMG446 for Eval set as IMG446_2
# Processed IMG493 for Eval set as IMG493_1
# Processed IMG307 for Eval set as IMG307_1
# Processed IMG475 for Eval set as IMG475_2
# Processed IMG254 for Eval set as IMG254_2
# Processed IMG304 for Eval set as IMG304_1
# Processed IMG089 for Eval set as IMG089_1
# Processed IMG199 for Eval set as IMG199_2
# Processed IMG087 for Eval set as IMG087_1
# Processed IMG355 for Test set as IMG355_4
# Processed IMG442 for Test set as IMG442_1
# Processed IMG127 for Test set as IMG127_1
# Processed IMG449 for Test set as IMG449_1
# Processed IMG069 for Test set as IMG069_1
# Processed IMG032 for Test set as IMG032_1
# Processed IMG255 for Test set as IMG255_1
# Processed IMG080 for Test set as IMG080_1
# Processed IMG430 for Test set as IMG430_1
# Processed IMG413 for Test set as IMG413_2
# Processed IMG060 for Test set as IMG060_2
# Processed IMG159 for Test set as IMG159_2
# Processed IMG401 for Test set as IMG401_1
# Processed IMG469 for Test set as IMG469_2
# Processed IMG074 for Test set as IMG074_1
# Processed IMG303 for Test set as IMG303_1
# Processed IMG432 for Test set as IMG432_1
# Processed IMG078 for Test set as IMG078_1
# Processed IMG195 for Test set as IMG195_1
# Processed IMG015 for Test set as IMG015_1
# Processed IMG092 for Test set as IMG092_1
# Processed IMG099 for Test set as IMG099_1
# Processed IMG126 for Test set as IMG126_1
# Processed IMG360 for Test set as IMG360_1
# Processed IMG071 for Test set as IMG071_1
# Processed IMG083 for Test set as IMG083_1
# Processed IMG281 for Test set as IMG281_1
# Processed IMG044 for Test set as IMG044_1
# Processed IMG184 for Test set as IMG184_5
# Processed IMG495 for Test set as IMG495_1
# Processed IMG072 for Test set as IMG072_1
# Processed IMG411 for Test set as IMG411_2
# Processed IMG144 for Test set as IMG144_2
# Processed IMG477 for Test set as IMG477_1
# Processed IMG472 for Test set as IMG472_1
# Processed IMG076 for Test set as IMG076_1
# Processed IMG440 for Test set as IMG440_1
# Processed IMG296 for Test set as IMG296_2
# Processed IMG296 for Test set as IMG296_3
# Processed IMG498 for Test set as IMG498_1
# Processed IMG492 for Test set as IMG492_1
# Processed IMG288 for Test set as IMG288_6
# Processed IMG469 for Test set as IMG469_3
# Processed IMG110 for Test set as IMG110_1
# Processed IMG497 for Test set as IMG497_2
# Processed IMG079 for Test set as IMG079_1
# Processed IMG037 for Test set as IMG037_1
# Processed IMG139 for Test set as IMG139_3
# Processed IMG485 for Test set as IMG485_1
# Processed IMG333 for Test set as IMG333_1
# Processed IMG412 for Test set as IMG412_3
# Processed IMG019 for Test set as IMG019_1
# Processed IMG452 for Test set as IMG452_1
# Processed IMG023 for Test set as IMG023_1
# Processed IMG357 for Test set as IMG357_5
# Processed IMG141 for Test set as IMG141_2
# Processed IMG001 for Test set as IMG001_2
# Processed IMG025 for Test set as IMG025_2
# Processed IMG356 for Test set as IMG356_1
# Processed IMG358 for Test set as IMG358_4
# Processed IMG060 for Test set as IMG060_3
# Processed IMG237 for Test set as IMG237_1
# Processed IMG490 for Test set as IMG490_1
# Processed IMG481 for Test set as IMG481_1
# Processed IMG290 for Test set as IMG290_1
# Processed IMG333 for Test set as IMG333_2
# Processed IMG442 for Test set as IMG442_2
# Processed IMG029 for Test set as IMG029_2
# Processed IMG433 for Test set as IMG433_2
# Processed IMG273 for Test set as IMG273_1
# Processed IMG331 for Test set as IMG331_2
# Processed IMG046 for Test set as IMG046_2
# Processed IMG204 for Test set as IMG204_2
# Processed IMG470 for Test set as IMG470_4
# Processed IMG286 for Test set as IMG286_6
# Processed IMG320 for Test set as IMG320_1
# Processed IMG356 for Test set as IMG356_2
# Processed IMG356 for Test set as IMG356_3
# Processed IMG028 for Test set as IMG028_2
# Processed IMG054 for Test set as IMG054_1
# Processed IMG484 for Test set as IMG484_1
# Processed IMG498 for Test set as IMG498_2
# Processed IMG496 for Test set as IMG496_1
# Processed IMG446 for Test set as IMG446_3
# Processed IMG061 for Test set as IMG061_2
# Processed IMG486 for Test set as IMG486_1
# Processed IMG029 for Test set as IMG029_3
